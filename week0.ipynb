# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsisripada/Machine-Learning/blob/main/week0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("svam.csv")
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 14 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   title                                                                          603 non-null    object
#  1   artist                                                                         603 non-null    object
#  2   the genre of the track                                                         603 non-null    object
#  3   year                                                                           603 non-null    int64
#  4   Beats.Per.Minute -The tempo of the song                                        603 non-null    int64
#  5   Energy- The energy of a song - the higher the value, the more energtic         603 non-null    int64
# ...

# %%
df.head()
# Out:
#                   title      artist the genre of the track  year  \
# 0      Hey, Soul Sister       Train             neo mellow  2010
# 1  Love The Way You Lie      Eminem        detroit hip hop  2010
# 2               TiK ToK       Kesha              dance pop  2010
# 3           Bad Romance   Lady Gaga              dance pop  2010
# 4  Just the Way You Are  Bruno Mars                    pop  2010
#
#    Beats.Per.Minute -The tempo of the song  \
# 0                                       97
# 1                                       87
# 2                                      120
# 3                                      119
# 4                                      109
#
#    Energy- The energy of a song - the higher the value, the more energtic  \
# 0                                                 89
# 1                                                 93
# 2                                                 84
# 3                                                 92
# ...

# %%
df.tail()
# Out:
#                                                  title            artist  \
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# 598              dance pop  2019                                      104
# 599                    pop  2019                                       95
# 600              dance pop  2019                                      136
# 601              dance pop  2019                                      114
# 602             electropop  2019                                      150
#
#      Energy- The energy of a song - the higher the value, the more energtic  \
# ...

# %%
df.shape
# Out:
# (603, 14)

# %%
df.describe()
# Out:
#               year  Beats.Per.Minute -The tempo of the song  \
# count   603.000000                               603.000000
# mean   2014.592040                               118.545605
# std       2.607057                                24.795358
# min    2010.000000                                 0.000000
# 25%    2013.000000                               100.000000
# 50%    2015.000000                               120.000000
# 75%    2017.000000                               129.000000
# max    2019.000000                               206.000000
#
#        Energy- The energy of a song - the higher the value, the more energtic  \
# count                                         603.000000
# mean                                           70.504146
# std                                            16.310664
# min                                             0.000000
# 25%                                            61.000000
# 50%                                            74.000000
# ...

# %%
df.isnull()
# Out:
#      title  artist  the genre of the track   year  \
# 0    False   False                   False  False
# 1    False   False                   False  False
# 2    False   False                   False  False
# 3    False   False                   False  False
# 4    False   False                   False  False
# ..     ...     ...                     ...    ...
# 598  False   False                   False  False
# 599  False   False                   False  False
# 600  False   False                   False  False
# 601  False   False                   False  False
# 602  False   False                   False  False
#
#      Beats.Per.Minute -The tempo of the song  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# ...

# %%
df.isnull().sum()
# Out:
# title                                                                            0
# artist                                                                           0
# the genre of the track                                                           0
# year                                                                             0
# Beats.Per.Minute -The tempo of the song                                          0
# Energy- The energy of a song - the higher the value, the more energtic           0
# Danceability - The higher the value, the easier it is to dance to this song      0
# Loudness/dB - The higher the value, the louder the song                          0
# Liveness - The higher the value, the more likely the song is a live recording    0
# Valence - The higher the value, the more positive mood for the song              0
# Length - The duration of the song                                                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 14 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   title                                                                          603 non-null    object
#  1   artist                                                                         603 non-null    object
#  2   the genre of the track                                                         603 non-null    object
#  3   year                                                                           603 non-null    int64
#  4   Beats.Per.Minute -The tempo of the song                                        603 non-null    int64
#  5   Energy- The energy of a song - the higher the value, the more energtic         603 non-null    int64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# Length: 603, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['title'].unique()
# Out:
# array(['Hey, Soul Sister', 'Love The Way You Lie', 'TiK ToK',
#        'Bad Romance', 'Just the Way You Are', 'Baby', 'Dynamite',
#        'Secrets', 'Empire State of Mind (Part II) Broken Down',
#        'Only Girl (In The World)',
#        "Club Can't Handle Me (feat. David Guetta)", 'Marry You',
#        'Cooler Than Me - Single Mix', 'Telephone', 'Like A G6',
#        'OMG (feat. will.i.am)', 'Eenie Meenie', 'The Time (Dirty Bit)',
#        'Alejandro', 'Your Love Is My Drug', 'Meet Me Halfway',
#        'Whataya Want from Me', 'Take It Off', 'Misery',
#        'All The Right Moves', 'Animal', 'Naturally', 'I Like It',
#        'Teenage Dream', 'California Gurls', '3',
#        'My First Kiss - feat. Ke$ha', 'Blah Blah Blah (feat. 3OH!3)',
#        'Imma Be', 'Try Sleeping with a Broken Heart',
#        'Sexy Bitch (feat. Akon)',
#        'Bound To You - Burlesque Original Motion Picture Soundtrack',
#        'If I Had You', 'Rock That Body', 'Dog Days Are Over',
# ...

# %%
df['artist']
# Out:
# 0                 Train
# 1                Eminem
# 2                 Kesha
# 3             Lady Gaga
# 4            Bruno Mars
#              ...
# 598         Mark Ronson
# 599          Ed Sheeran
# 600           DJ Khaled
# 601         Mark Ronson
# 602    The Chainsmokers
# Name: artist, Length: 603, dtype: object

# %%
df.artist.loc[:].unique()
# Out:
# array(['Train', 'Eminem', 'Kesha', 'Lady Gaga', 'Bruno Mars',
#        'Justin Bieber', 'Taio Cruz', 'OneRepublic', 'Alicia Keys',
#        'Rihanna', 'Flo Rida', 'Mike Posner', 'Far East Movement', 'Usher',
#        'Sean Kingston', 'The Black Eyed Peas', 'Adam Lambert', 'Maroon 5',
#        'Neon Trees', 'Selena Gomez & The Scene', 'Enrique Iglesias',
#        'Katy Perry', 'Britney Spears', '3OH!3', 'David Guetta',
#        'Christina Aguilera', 'Florence + The Machine', 'Shakira',
#        'Tinie Tempah', 'T.I.', 'Martin Solveig', 'Christina Perri',
#        'Adele', 'Pitbull', 'Beyonce', 'Hot Chelle Rae', 'Avril Lavigne',
#        'Kanye West', 'LMFAO', 'Jessie J', 'Jennifer Lopez', 'Chris Brown',
#        'Sleeping At Last', 'Nicki Minaj', 'P!nk', 'Coldplay',
#        'One Direction', 'Taylor Swift', 'Carly Rae Jepsen',
#        'Kelly Clarkson', 'Owl City', 'The Wanted', 'fun.',
#        'Ellie Goulding', 'Gym Class Heroes', 'Avicii', 'The Script',
# ...

# %%
df.groupby(['artist','title']).mean()
# Out:
#                                                                           year  \
# artist              title
# 3OH!3               My First Kiss - feat. Ke$ha                         2010.0
# 5 Seconds of Summer She Looks So Perfect                                2014.0
# A Great Big World   Say Something                                       2014.0
# Adam Lambert        If I Had You                                        2010.0
#                     Whataya Want from Me                                2010.0
# ...                                                                        ...
# Zedd                Stay The Night - Featuring Hayley Williams Of P...  2014.0
#                     True Colors                                         2016.0
# fun.                Some Nights                                         2012.0
#                     We Are Young (feat. Janelle Mon醗)                   2012.0
# ...

# %%
df.groupby(['artist','title']).std()
# Out:
#                                                                         year  \
# artist              title
# 3OH!3               My First Kiss - feat. Ke$ha                          NaN
# 5 Seconds of Summer She Looks So Perfect                                 NaN
# A Great Big World   Say Something                                        NaN
# Adam Lambert        If I Had You                                         NaN
#                     Whataya Want from Me                                 NaN
# ...                                                                      ...
# Zedd                Stay The Night - Featuring Hayley Williams Of P...   NaN
#                     True Colors                                          NaN
# fun.                Some Nights                                          NaN
#                     We Are Young (feat. Janelle Mon醗)                    NaN
# will.i.am           #thatPOWER                                           NaN
#
# ...

# %%
df.isnull().count()
# Out:
# title                                                                            603
# artist                                                                           603
# the genre of the track                                                           603
# year                                                                             603
# Beats.Per.Minute -The tempo of the song                                          603
# Energy- The energy of a song - the higher the value, the more energtic           603
# Danceability - The higher the value, the easier it is to dance to this song      603
# Loudness/dB - The higher the value, the louder the song                          603
# Liveness - The higher the value, the more likely the song is a live recording    603
# Valence - The higher the value, the more positive mood for the song              603
# Length - The duration of the song                                                603
# ...

# %%
import matplotlib.pyplot as plt
y=df['Beats.Per.Minute -The tempo of the song']
plt.figure(figsize=(15,20))
plt.boxplot(y)
plt.show()

# %%
y=list(df['Beats.Per.Minute -The tempo of the song'])
plt.hist(y)
plt.show()

# %%
x=list(df['artist'])
plt.figure(figsize=(20,7))
plt.bar(x,y)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 7))
sns.heatmap(df.drop(['artist','title'],axis=1).corr())
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 7))
sns.pairplot(df.drop(['artist','Beats.Per.Minute -The tempo of the song'],axis=1).corr())
plt.show()

# %%
df.dtypes
# Out:
# title                                                                            object
# artist                                                                           object
# the genre of the track                                                           object
# year                                                                              int64
# Beats.Per.Minute -The tempo of the song                                           int64
# Energy- The energy of a song - the higher the value, the more energtic            int64
# Danceability - The higher the value, the easier it is to dance to this song       int64
# Loudness/dB - The higher the value, the louder the song                           int64
# Liveness - The higher the value, the more likely the song is a live recording     int64
# Valence - The higher the value, the more positive mood for the song               int64
# Length - The duration of the song                                                 int64
# ...

# %%
df.dropna(subset=['artist'])
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# ...

# %%
df=df.replace(1399,"nan")
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# ...
